# %%
import numpy as np
import sklearn
import pandas as pd

# %%
df = pd.read_csv("train_electricity.csv")

print("Dataset has", len(df), "entries.")

print(f"\n\t{'Column':20s} | {'Type':8s} | {'Min':12s} | {'Max':12s}\n")
for col_name in df.columns:
    col = df[col_name]
    print(f"\t{col_name:20s} | {str(col.dtype):8s} | {col.min():12.1f} | {col.max():12.1f}")
# Out:
# Dataset has 419403 entries.
#
# 	Column               | Type     | Min          | Max
#
# 	Date                 | int64    | 1262487660.0 | 1514947775.0
# 	Consumption_MW       | float64  |         44.0 |      26209.0
# 	Coal_MW              | float64  |       -485.0 |       5702.0
# 	Gas_MW               | float64  |       -414.0 |       2666.0
# 	Hidroelectric_MW     | float64  |          0.0 |       4728.0
# 	Nuclear_MW           | float64  |          0.0 |       1450.0
# 	Wind_MW              | float64  |       -521.0 |       7944.0
# 	Solar_MW             | float64  |         -6.0 |        859.0
# 	Biomass_MW           | float64  |          0.0 |        110.0
# 	Production_MW        | float64  |          0.0 |      11295.0

# %%
## 2. Adding some datetime related features

def add_datetime_features(df):
    features = ["Year", "Week", "Day", "Dayofyear", "Month", "Dayofweek",
                "Is_year_end", "Is_year_start", "Is_month_end", "Is_month_start",
                "Hour", "Minute",]
    one_hot_features = ["Month", "Dayofweek"]

    datetime = pd.to_datetime(df.Date * (10 ** 9))

    df['Datetime'] = datetime  # We won't use this for training, but we'll remove it later

    for feature in features:
        new_column = getattr(datetime.dt, feature.lower())
        if feature in one_hot_features:
            df = pd.concat([df, pd.get_dummies(new_column, prefix=feature)], axis=1)
        else:
            df[feature] = new_column
    return df

df = add_datetime_features(df)
df.columns
# Out:
# Index(['Date', 'Consumption_MW', 'Coal_MW', 'Gas_MW', 'Hidroelectric_MW',
#        'Nuclear_MW', 'Wind_MW', 'Solar_MW', 'Biomass_MW', 'Production_MW',
#        'Datetime', 'Year', 'Week', 'Day', 'Dayofyear', 'Month_1', 'Month_2',
#        'Month_3', 'Month_4', 'Month_5', 'Month_6', 'Month_7', 'Month_8',
#        'Month_9', 'Month_10', 'Month_11', 'Month_12', 'Dayofweek_0',
#        'Dayofweek_1', 'Dayofweek_2', 'Dayofweek_3', 'Dayofweek_4',
#        'Dayofweek_5', 'Dayofweek_6', 'Is_year_end', 'Is_year_start',
#        'Is_month_end', 'Is_month_start', 'Hour', 'Minute'],
#       dtype='object')

# %%
## 3. Split data into train / validation (leaving the last six months for validation)

from dateutil.relativedelta import relativedelta

eval_from = df['Datetime'].max() + relativedelta(months=-6)  # Here we set the 6 months threshold
train_df = df[df['Datetime'] < eval_from]
valid_df = df[df['Datetime'] >= eval_from]

print(f"Train data: {train_df['Datetime'].min()} -> {train_df['Datetime'].max()} | {len(train_df)} samples.")
print(f"Valid data: {valid_df['Datetime'].min()} -> {valid_df['Datetime'].max()} | {len(valid_df)} samples.")
# Out:
# Train data: 2010-01-03 03:01:00 -> 2017-07-03 02:43:44 | 392461 samples.
# Valid data: 2017-07-03 02:53:34 -> 2018-01-03 02:49:35 | 26942 samples.

# %%
## 4. Prepare data for XGBoosting (DataFrame --> DMatrix)

import xgboost as xgb

label_col = "Consumption_MW"  # The target values are in this column
to_drop = [label_col, "Date", "Datetime"]  # Columns we do not need for training

xg_trn_data = xgb.DMatrix(train_df.drop(columns=to_drop), label=train_df[label_col])
xg_vld_data = xgb.DMatrix(valid_df.drop(columns=to_drop), label=valid_df[label_col])
# Out:
# /Users/shivangi/Desktop/Masters/Sem3/ADL/adl4cv_practikum/venv/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/shivangi/Desktop/Masters/Sem3/ADL/adl4cv_practikum/venv/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
## 5. Train (mostly with default parameters; it overfits like hell)
num_round = 300
xgb_param = {"objective": "reg:squarederror" if xgb.__version__ > '0.82' else 'reg:linear',
            'eta': 0.1, 'booster': 'gbtree', 'max_depth': 5}
watchlist = [(xg_trn_data, "train"), (xg_vld_data, "valid")]

bst = xgb.train(xgb_param, xg_trn_data, num_round, watchlist)
# Out:
# [0]	train-rmse:6003	valid-rmse:6268.89
# [1]	train-rmse:5405	valid-rmse:5676.09
# [2]	train-rmse:4866.97	valid-rmse:5145.04
# [3]	train-rmse:4382.97	valid-rmse:4668.05
# [4]	train-rmse:3947.54	valid-rmse:4237.93
# [5]	train-rmse:3555.93	valid-rmse:3846.19
# [6]	train-rmse:3203.62	valid-rmse:3496.25
# [7]	train-rmse:2886.87	valid-rmse:3184.39
# [8]	train-rmse:2602	valid-rmse:2898.13
# [9]	train-rmse:2345.94	valid-rmse:2639.74
# [10]	train-rmse:2115.87	valid-rmse:2405.6
# [11]	train-rmse:1909.15	valid-rmse:2193.43
# [12]	train-rmse:1723.3	valid-rmse:2006.79
# [13]	train-rmse:1556.63	valid-rmse:1840.91
# [14]	train-rmse:1406.97	valid-rmse:1678.69
# [15]	train-rmse:1272.7	valid-rmse:1542.74
# [16]	train-rmse:1152.28	valid-rmse:1421.52
# [17]	train-rmse:1044.56	valid-rmse:1303.82
# [18]	train-rmse:948.282	valid-rmse:1203.31
# [19]	train-rmse:861.91	valid-rmse:1112.92
# [20]	train-rmse:785.227	valid-rmse:1038.98
# [21]	train-rmse:716.919	valid-rmse:970.202
# [22]	train-rmse:655.579	valid-rmse:906.738
# [23]	train-rmse:601.609	valid-rmse:847.369
# [24]	train-rmse:553.54	valid-rmse:791.724
# [25]	train-rmse:511.253	valid-rmse:744.479
# [26]	train-rmse:473.883	valid-rmse:701.994
# [27]	train-rmse:440.66	valid-rmse:672.377
# [28]	train-rmse:411.862	valid-rmse:631.688
# [29]	train-rmse:386.469	valid-rmse:602.691
# [30]	train-rmse:363.834	valid-rmse:571.375
# [31]	train-rmse:344.622	valid-rmse:547.451
# [32]	train-rmse:328.016	valid-rmse:525.973
# [33]	train-rmse:313.308	valid-rmse:514.317
# [34]	train-rmse:300.454	valid-rmse:501.672
# [35]	train-rmse:289.853	valid-rmse:482.819
# [36]	train-rmse:280.706	valid-rmse:471.554
# [37]	train-rmse:272.642	valid-rmse:463.461
# [38]	train-rmse:265.764	valid-rmse:453.623
# [39]	train-rmse:260.027	valid-rmse:443.868
# [40]	train-rmse:254.843	valid-rmse:438.109
# [41]	train-rmse:250.554	valid-rmse:428.154
# [42]	train-rmse:246.802	valid-rmse:423.115
# [43]	train-rmse:243.347	valid-rmse:417.459
# [44]	train-rmse:240.461	valid-rmse:413.986
# [45]	train-rmse:237.755	valid-rmse:406.337
# [46]	train-rmse:235.397	valid-rmse:397.62
# [47]	train-rmse:232.616	valid-rmse:393.989
# [48]	train-rmse:230.436	valid-rmse:388.882
# [49]	train-rmse:228.689	valid-rmse:383.72
# [50]	train-rmse:226.75	valid-rmse:381.842
# [51]	train-rmse:224.566	valid-rmse:380.896
# [52]	train-rmse:223.008	valid-rmse:377.904
# [53]	train-rmse:221.912	valid-rmse:375.482
# [54]	train-rmse:220.602	valid-rmse:374.583
# [55]	train-rmse:219.13	valid-rmse:372.923
# [56]	train-rmse:217.739	valid-rmse:366.406
# [57]	train-rmse:216.816	valid-rmse:363.987
# [58]	train-rmse:215.869	valid-rmse:363.365
# [59]	train-rmse:215.47	valid-rmse:363.071
# [60]	train-rmse:214.355	valid-rmse:362.824
# [61]	train-rmse:212.965	valid-rmse:361.686
# [62]	train-rmse:212.115	valid-rmse:360.324
# [63]	train-rmse:211.633	valid-rmse:359.333
# [64]	train-rmse:210.679	valid-rmse:358.882
# [65]	train-rmse:209.96	valid-rmse:357.759
# [66]	train-rmse:209.268	valid-rmse:354.343
# [67]	train-rmse:209.033	valid-rmse:354.341
# [68]	train-rmse:208.134	valid-rmse:352.064
# [69]	train-rmse:207.252	valid-rmse:351.378
# [70]	train-rmse:206.709	valid-rmse:351.087
# [71]	train-rmse:206.471	valid-rmse:351.287
# [72]	train-rmse:205.588	valid-rmse:351.222
# [73]	train-rmse:204.919	valid-rmse:347.352
# [74]	train-rmse:204.242	valid-rmse:345.553
# [75]	train-rmse:203.645	valid-rmse:345.871
# [76]	train-rmse:203.268	valid-rmse:345.853
# [77]	train-rmse:202.863	valid-rmse:345.475
# [78]	train-rmse:202.431	valid-rmse:343.681
# [79]	train-rmse:201.219	valid-rmse:342.869
# [80]	train-rmse:200.787	valid-rmse:343.003
# [81]	train-rmse:200.253	valid-rmse:342.086
# [82]	train-rmse:199.584	valid-rmse:342.068
# [83]	train-rmse:199.083	valid-rmse:341.249
# [84]	train-rmse:198.873	valid-rmse:341.32
# [85]	train-rmse:198.627	valid-rmse:340.961
# [86]	train-rmse:198.102	valid-rmse:339.649
# [87]	train-rmse:197.481	valid-rmse:339.315
# [88]	train-rmse:197.068	valid-rmse:338.642
# [89]	train-rmse:196.754	valid-rmse:338.8
# [90]	train-rmse:196.359	valid-rmse:337.954
# [91]	train-rmse:195.837	valid-rmse:336.744
# [92]	train-rmse:195.319	valid-rmse:335.604
# [93]	train-rmse:194.793	valid-rmse:335.06
# [94]	train-rmse:194.336	valid-rmse:335.338
# [95]	train-rmse:194.005	valid-rmse:335.383
# [96]	train-rmse:193.478	valid-rmse:335.121
# [97]	train-rmse:193.156	valid-rmse:334.82
# [98]	train-rmse:192.687	valid-rmse:332.325
# [99]	train-rmse:192.264	valid-rmse:332.164
# [100]	train-rmse:191.892	valid-rmse:330.808
# [101]	train-rmse:191.728	valid-rmse:330.706
# [102]	train-rmse:191.432	valid-rmse:330.335
# [103]	train-rmse:190.569	valid-rmse:330.806
# [104]	train-rmse:190.329	valid-rmse:330.483
# [105]	train-rmse:190.067	valid-rmse:330.119
# [106]	train-rmse:189.733	valid-rmse:329.226
# [107]	train-rmse:189.435	valid-rmse:328.923
# [108]	train-rmse:189.119	valid-rmse:327.923
# [109]	train-rmse:188.65	valid-rmse:328.419
# [110]	train-rmse:188.436	valid-rmse:328.156
# [111]	train-rmse:188.18	valid-rmse:327.52
# [112]	train-rmse:187.991	valid-rmse:327.601
# [113]	train-rmse:187.692	valid-rmse:327.305
# [114]	train-rmse:187.008	valid-rmse:324.677
# [115]	train-rmse:186.789	valid-rmse:324.809
# [116]	train-rmse:186.535	valid-rmse:324.465
# [117]	train-rmse:186.218	valid-rmse:323.649
# [118]	train-rmse:186.038	valid-rmse:323.949
# [119]	train-rmse:185.772	valid-rmse:322.699
# [120]	train-rmse:185.487	valid-rmse:322.846
# [121]	train-rmse:185.076	valid-rmse:322.303
# [122]	train-rmse:184.729	valid-rmse:321.275
# [123]	train-rmse:184.514	valid-rmse:321.058
# [124]	train-rmse:184.101	valid-rmse:320.756
# [125]	train-rmse:183.757	valid-rmse:320.364
# [126]	train-rmse:183.424	valid-rmse:320.326
# [127]	train-rmse:183.253	valid-rmse:320.311
# [128]	train-rmse:182.954	valid-rmse:320.157
# [129]	train-rmse:182.795	valid-rmse:320.033
# [130]	train-rmse:182.657	valid-rmse:319.869
# [131]	train-rmse:182.352	valid-rmse:320.089
# [132]	train-rmse:182.058	valid-rmse:320.174
# [133]	train-rmse:181.831	valid-rmse:319.659
# [134]	train-rmse:181.597	valid-rmse:319.058
# [135]	train-rmse:181.284	valid-rmse:319.274
# [136]	train-rmse:181.091	valid-rmse:319.17
# [137]	train-rmse:180.63	valid-rmse:319.305
# [138]	train-rmse:180.489	valid-rmse:319.305
# [139]	train-rmse:179.959	valid-rmse:319.903
# [140]	train-rmse:179.879	valid-rmse:319.81
# [141]	train-rmse:179.471	valid-rmse:319.118
# [142]	train-rmse:179.135	valid-rmse:318.881
# [143]	train-rmse:179.014	valid-rmse:318.627
# [144]	train-rmse:178.842	valid-rmse:318.531
# [145]	train-rmse:178.604	valid-rmse:317.864
# [146]	train-rmse:178.53	valid-rmse:317.841
# [147]	train-rmse:178.353	valid-rmse:317.549
# [148]	train-rmse:178.033	valid-rmse:317.144
# [149]	train-rmse:177.743	valid-rmse:316.983
# [150]	train-rmse:177.533	valid-rmse:316.511
# [151]	train-rmse:177.352	valid-rmse:316.485
# [152]	train-rmse:177.118	valid-rmse:316.769
# [153]	train-rmse:176.744	valid-rmse:316.756
# [154]	train-rmse:176.525	valid-rmse:316.77
# [155]	train-rmse:176.482	valid-rmse:316.817
# [156]	train-rmse:176.065	valid-rmse:316.029
# [157]	train-rmse:175.81	valid-rmse:315.878
# [158]	train-rmse:175.347	valid-rmse:316.17
# [159]	train-rmse:175.296	valid-rmse:316.081
# [160]	train-rmse:174.961	valid-rmse:316.085
# [161]	train-rmse:174.655	valid-rmse:315.469
# [162]	train-rmse:174.474	valid-rmse:313.557
# [163]	train-rmse:174.289	valid-rmse:313.358
# [164]	train-rmse:174.152	valid-rmse:312.918
# [165]	train-rmse:173.977	valid-rmse:312.073
# [166]	train-rmse:173.762	valid-rmse:312.359
# [167]	train-rmse:173.601	valid-rmse:312.209
# [168]	train-rmse:173.459	valid-rmse:312.048
# [169]	train-rmse:173.384	valid-rmse:311.944
# [170]	train-rmse:173.028	valid-rmse:312.015
# [171]	train-rmse:172.672	valid-rmse:311.791
# [172]	train-rmse:172.562	valid-rmse:311.635
# [173]	train-rmse:172.53	valid-rmse:311.62
# [174]	train-rmse:172.436	valid-rmse:311.505
# [175]	train-rmse:171.92	valid-rmse:311.66
# [176]	train-rmse:171.819	valid-rmse:311.22
# [177]	train-rmse:171.587	valid-rmse:311.311
# [178]	train-rmse:171.462	valid-rmse:311.17
# [179]	train-rmse:171.328	valid-rmse:311.113
# [180]	train-rmse:171.23	valid-rmse:310.763
# [181]	train-rmse:171.058	valid-rmse:310.823
# [182]	train-rmse:170.608	valid-rmse:310.883
# [183]	train-rmse:170.563	valid-rmse:310.846
# [184]	train-rmse:170.408	valid-rmse:310.683
# [185]	train-rmse:170.078	valid-rmse:310.862
# [186]	train-rmse:169.938	valid-rmse:310.64
# [187]	train-rmse:169.708	valid-rmse:310.504
# [188]	train-rmse:169.273	valid-rmse:309.856
# [189]	train-rmse:169.132	valid-rmse:310.204
# [190]	train-rmse:168.971	valid-rmse:310.033
# [191]	train-rmse:168.851	valid-rmse:309.838
# [192]	train-rmse:168.473	valid-rmse:309.723
# [193]	train-rmse:168.3	valid-rmse:309.348
# [194]	train-rmse:168.014	valid-rmse:307.924
# [195]	train-rmse:167.937	valid-rmse:307.474
# [196]	train-rmse:167.662	valid-rmse:307.039
# [197]	train-rmse:167.478	valid-rmse:307.257
# [198]	train-rmse:167.232	valid-rmse:306.921
# [199]	train-rmse:167.107	valid-rmse:306.674
# [200]	train-rmse:166.888	valid-rmse:306.415
# [201]	train-rmse:166.548	valid-rmse:306.776
# [202]	train-rmse:166.285	valid-rmse:306.886
# [203]	train-rmse:166.26	valid-rmse:306.878
# [204]	train-rmse:165.925	valid-rmse:306.751
# [205]	train-rmse:165.882	valid-rmse:306.64
# [206]	train-rmse:165.738	valid-rmse:306.313
# [207]	train-rmse:165.629	valid-rmse:306.141
# [208]	train-rmse:165.309	valid-rmse:305.995
# [209]	train-rmse:165.136	valid-rmse:305.813
# [210]	train-rmse:164.884	valid-rmse:305.838
# [211]	train-rmse:164.589	valid-rmse:304.49
# [212]	train-rmse:164.416	valid-rmse:304.268
# [213]	train-rmse:164.28	valid-rmse:304.158
# [214]	train-rmse:164.008	valid-rmse:303.622
# [215]	train-rmse:163.84	valid-rmse:303.57
# [216]	train-rmse:163.721	valid-rmse:303.342
# [217]	train-rmse:163.508	valid-rmse:302.743
# [218]	train-rmse:163.251	valid-rmse:302.351
# [219]	train-rmse:162.983	valid-rmse:302.308
# [220]	train-rmse:162.697	valid-rmse:300.327
# [221]	train-rmse:162.518	valid-rmse:300.122
# [222]	train-rmse:162.315	valid-rmse:300.052
# [223]	train-rmse:162.108	valid-rmse:300.035
# [224]	train-rmse:161.98	valid-rmse:300.065
# [225]	train-rmse:161.756	valid-rmse:299.663
# [226]	train-rmse:161.558	valid-rmse:299.474
# [227]	train-rmse:161.275	valid-rmse:299.354
# [228]	train-rmse:161.142	valid-rmse:298.945
# [229]	train-rmse:161.098	valid-rmse:299.012
# [230]	train-rmse:161.003	valid-rmse:299.129
# [231]	train-rmse:160.957	valid-rmse:299.037
# [232]	train-rmse:160.747	valid-rmse:299.204
# [233]	train-rmse:160.614	valid-rmse:299.222
# [234]	train-rmse:160.472	valid-rmse:298.847
# [235]	train-rmse:160.412	valid-rmse:298.852
# [236]	train-rmse:160.32	valid-rmse:298.755
# [237]	train-rmse:160.272	valid-rmse:298.707
# [238]	train-rmse:160.169	valid-rmse:298.734
# [239]	train-rmse:160.044	valid-rmse:298.567
# [240]	train-rmse:159.914	valid-rmse:298.313
# [241]	train-rmse:159.73	valid-rmse:298.327
# [242]	train-rmse:159.553	valid-rmse:298.386
# [243]	train-rmse:159.425	valid-rmse:298.25
# [244]	train-rmse:159.238	valid-rmse:297.419
# [245]	train-rmse:159.11	valid-rmse:297.086
# [246]	train-rmse:158.957	valid-rmse:296.985
# [247]	train-rmse:158.933	valid-rmse:296.982
# [248]	train-rmse:158.88	valid-rmse:296.983
# [249]	train-rmse:158.577	valid-rmse:297.243
# [250]	train-rmse:158.484	valid-rmse:297.122
# [251]	train-rmse:158.255	valid-rmse:296.869
# [252]	train-rmse:158.081	valid-rmse:296.992
# [253]	train-rmse:157.954	valid-rmse:296.897
# [254]	train-rmse:157.902	valid-rmse:296.863
# [255]	train-rmse:157.857	valid-rmse:296.922
# [256]	train-rmse:157.827	valid-rmse:296.945
# [257]	train-rmse:157.789	valid-rmse:296.881
# [258]	train-rmse:157.676	valid-rmse:296.904
# [259]	train-rmse:157.617	valid-rmse:296.54
# [260]	train-rmse:157.582	valid-rmse:296.464
# [261]	train-rmse:157.49	valid-rmse:296.476
# [262]	train-rmse:157.172	valid-rmse:296.05
# [263]	train-rmse:157.009	valid-rmse:295.7
# [264]	train-rmse:156.868	valid-rmse:294.032
# [265]	train-rmse:156.853	valid-rmse:294.035
# [266]	train-rmse:156.83	valid-rmse:294.031
# [267]	train-rmse:156.705	valid-rmse:293.878
# [268]	train-rmse:156.518	valid-rmse:293.797
# [269]	train-rmse:156.386	valid-rmse:293.793
# [270]	train-rmse:156.062	valid-rmse:293.098
# [271]	train-rmse:155.976	valid-rmse:293.104
# [272]	train-rmse:155.922	valid-rmse:293.072
# [273]	train-rmse:155.843	valid-rmse:293.066
# [274]	train-rmse:155.812	valid-rmse:293.107
# [275]	train-rmse:155.679	valid-rmse:293.084
# [276]	train-rmse:155.658	valid-rmse:292.998
# [277]	train-rmse:155.457	valid-rmse:293.147
# [278]	train-rmse:155.324	valid-rmse:293.003
# [279]	train-rmse:155.141	valid-rmse:292.629
# [280]	train-rmse:155.018	valid-rmse:292.511
# [281]	train-rmse:154.921	valid-rmse:292.604
# [282]	train-rmse:154.799	valid-rmse:292.658
# [283]	train-rmse:154.559	valid-rmse:292.877
# [284]	train-rmse:154.508	valid-rmse:292.884
# [285]	train-rmse:154.366	valid-rmse:292.849
# [286]	train-rmse:154.295	valid-rmse:292.853
# [287]	train-rmse:154.175	valid-rmse:292.923
# [288]	train-rmse:153.993	valid-rmse:292.216
# [289]	train-rmse:153.874	valid-rmse:292.156
# [290]	train-rmse:153.74	valid-rmse:292.068
# [291]	train-rmse:153.631	valid-rmse:292.013
# [292]	train-rmse:153.427	valid-rmse:291.977
# [293]	train-rmse:153.295	valid-rmse:292.011
# [294]	train-rmse:153.005	valid-rmse:292.17
# [295]	train-rmse:152.859	valid-rmse:292.118
# [296]	train-rmse:152.768	valid-rmse:292.181
# [297]	train-rmse:152.732	valid-rmse:292.177
# [298]	train-rmse:152.647	valid-rmse:292.159
# [299]	train-rmse:152.547	valid-rmse:292.096

# %%
## 6. Read test dataset, use the bst for prediction, save submission csv

test_df = pd.read_csv("input/test_electricity.csv")
test_df = add_datetime_features(test_df)
xgb_test_data = xgb.DMatrix(test_df.drop(columns=["Date", "Datetime"]))

solution_df = pd.DataFrame(test_df["Date"])
solution_df["Consumption_MW"] = bst.predict(xgb_test_data)
solution_df.to_csv("sample_submission.csv", index=False)
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-967893d734e4> in <module>
#       1 ## 6. Read test dataset, use the bst for prediction, save submission csv
#       2
# ----> 3 test_df = pd.read_csv("input/test_electricity.csv")
#       4 test_df = add_datetime_features(test_df)
#       5 xgb_test_data = xgb.DMatrix(test_df.drop(columns=["Date", "Datetime"]))
#
# NameError: name 'pd' is not defined
